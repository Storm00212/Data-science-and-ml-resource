# %% [markdown]
# <a href="https://colab.research.google.com/github/Storm00212/Data-science-and-ml-resource/blob/main/Reading_data_from_tweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
# !apt-get install -y wkhtmltopdf --quiet
# !pip install pdfkit --quiet

import pdfkit
#loading dataframes as json format
dataframes = {
    "df1": df1,
    "df2": df2,
    "df3": df3,
    "df4": df4,
    "df5": df5
}
# converting them to pdf

for name, df in dataframes.items():
    if not df.empty:
        html_string = df.to_html()
        pdfkit.from_string(html_string, f"{name}.pdf")
        print(f"Successfully converted {name} to {name}.pdf")
        files.download(f"{name}.pdf")
    else:
        print(f"DataFrame {name} is empty, skipping PDF conversion.")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# wkhtmltopdf is already the newest version (0.12.6-2).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# Successfully converted df1 to df1.pdf
# Successfully converted df2 to df2.pdf
# Successfully converted df3 to df3.pdf
# Successfully converted df4 to df4.pdf
# DataFrame df5 is empty, skipping PDF conversion.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path1="/content/drive/MyDrive/Data/MIXED.csv"
df1 = pd.read_csv(file_path1)
print(len(df1))
df1.head()
# Out:
# 6
#                  author                                               text  \
# 0         @davecooke914        What a player he was we miss him up front 👍
# 1       @AliAhmed-tc7qg  Humble, generous and person and brilliant play...
# 2  @adeyemigodsight5994             Great player, but Salah is way better.
# 3      @glyndwrjohn6383  Great player but I still find it creepy that h...
# 4  @AhmedMohammed-m5b4i  Why does he hate Salah so much? We all know Sa...
#
#   sentiment                                     emotion_scores
# 0     MIXED  {"Positive": 0.05123357102274895, "Negative": ...
# 1     MIXED  {"Positive": 0.13133636116981506, "Negative": ...
# 2     MIXED  {"Positive": 0.009891095571219921, "Negative":...
# 3     MIXED  {"Positive": 0.00842260755598545, "Negative": ...
# 4     MIXED  {"Positive": 0.05708245560526848, "Negative": ...

# %%
file_path2="/content/drive/MyDrive/Data/NEGATIVE.csv"
df2=pd.read_csv(file_path2)
print(len(df2))
df2.head()
# Out:
# 67
#                author                                               text  \
# 0          @Monan_Ksl  I’ve memorized every single letter in the vide...
# 1       @kana-kun5471                              Damnit. Got me again.
# 2        @robbruh1661                           god dang it not again...
# 3  @francespastor4682                                      Not cool man😢
# 4    @EricProlsdorfer  Todays empowered girl is not attracted to this...
#
#   sentiment                                     emotion_scores
# 0  NEGATIVE  {"Positive": 0.07366892695426941, "Negative": ...
# 1  NEGATIVE  {"Positive": 0.07691729068756104, "Negative": ...
# 2  NEGATIVE  {"Positive": 0.044121623039245605, "Negative":...
# 3  NEGATIVE  {"Positive": 0.00020476414647419006, "Negative...
# 4  NEGATIVE  {"Positive": 0.018734484910964966, "Negative":...

# %%
file_path3="/content/drive/MyDrive/Data/POSITIVE.csv"
df3=pd.read_csv(file_path3)
print(len(df3))
df3.head()
# Out:
# 194
#           author                                               text sentiment  \
# 0       @YouTube                   can confirm: he never gave us up  POSITIVE
# 1  @meliomaradin                                 this is a legend\n  POSITIVE
# 2     @Alazybean  Ima Rick a roll my friend so I can earn back h...  POSITIVE
# 3     @cuzzman01  Man, I just got Rick rolled by my AI, I was bu...  POSITIVE
# 4     @MOUAADH11  شكرا جزيلا ❤❤ هادي أفضل جائزة تحصلت عليها و ال...  POSITIVE
#
#                                       emotion_scores
# 0  {"Positive": 0.7587594985961914, "Negative": 0...
# 1  {"Positive": 0.9188109636306763, "Negative": 0...
# 2  {"Positive": 0.8105863332748413, "Negative": 0...
# 3  {"Positive": 0.5777423977851868, "Negative": 0...
# 4  {"Positive": 0.999576985836029, "Negative": 7....

# %%
file_path4="/content/drive/MyDrive/Data/youtube_all_comments_xQ3MzNPmCxk_20251121T122030Z.csv"
df4=pd.read_csv(file_path4)
print(len(df4))
df4.head()
# Out:
# 50
#                     author                                               text  \
# 0  @michaelghebretnsae7990                            Liverpool lives lifes ❤
# 1          @velithwala2815                     Best interview. Just excellent
# 2             @TumeloTheka                          I love it here now 1time!
# 3             @NoraHay-r1w  Sadio Mané is one of those BPL legends that ha...
# 4     @RosemaryNduta-c7p8k    I miss klopp. Slot should learn alot from klopp
#
#   sentiment                                     emotion_scores
# 0  POSITIVE  {'Positive': 0.9378771781921387, 'Negative': 0...
# 1  POSITIVE  {'Positive': 0.9997028708457947, 'Negative': 6...
# 2  POSITIVE  {'Positive': 0.9986144304275513, 'Negative': 0...
# 3  NEGATIVE  {'Positive': 0.35473427176475525, 'Negative': ...
# 4  NEGATIVE  {'Positive': 0.03097255527973175, 'Negative': ...

# %%
file_path5="/content/drive/MyDrive/Data/youtube_stalkers_xQ3MzNPmCxk_20251121T122030Z.csv"
df5=pd.read_csv(file_path5)
print(len(df5))
df5.head()
# Out:
# 0
# Empty DataFrame
# Columns: [author, count, last_text]
# Index: []

# %%
import pdfkit
